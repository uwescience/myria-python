# %% [markdown]
# For more info on Myria, access to the demo cluster, and setting up a cluster: http://myria.cs.washington.edu/

# %% [markdown]
# ## Connecting to Myria

# %%
# myria-python functionality
from myria import *

# myriaL cell functionality
# %load_ext myria

# connection for myria-python functionality
connection = MyriaConnection(rest_url='http://localhost:8753')
# same as: http://ec2-52-36-55-94.us-west-2.compute.amazonaws.com:8753

# connection for myriaL cell functionality
# %connect http://localhost:8753

# %% [markdown]
# ## MyriaL Basics

# %% [markdown]
# First you would scan in whatever tables you want to use in that cell.
# These are the tables visible in the Myria-Web datasets tab.
#
# ```
# R1 = scan(cosmo8_000970);
# ```
# This put all of the data in the `cosmo8_000970` table into the relation `R1` which can now be queried with MyriaL
#
# ```
# R2 = select * from R1 limit 5;
# ```
# Once we have a relation, we can query it, and store the result in a new relation.
# Sometimes you just want to see the output of the cell you're running, or sometimes you want to store the result for later use. In either case, you have to `store` the relation that you want to see or store the output of, because otherwise Myria will optimize the query into an empty query.
# ```
# store(R2, MyInterestingResult);
# ```
# This will add `MyInterestingResult` to the list of datasets on Myria-Web. If you are running multiple queries and want to just see their results without storing multiple new tables, you can pick a name and overwrite it repeatedly:
# ```
# %%query
#     ...
#     store(R2, temp);
# ...
# query%%
#     ...
#     store(R50, temp);
# ```
#
# All statements need to be ended with a semicolon!
#
# Also, note that a MyriaL cell cannot contain any Python.
# These cells are Python by default, but a MyriaL cell starts with `%%query` and can only contain MyriaL syntax.

# %%
# %%query
# -- comments in MyriaL look like this
# -- notice that the notebook highlighting still thinks we are writing python: in, from, for, range, return
#
# R1 = scan(cosmo8_000970);
# R2 = select * from R1 limit 5;
# R3 = select iOrder from R1 limit 5;
# store(R2, garbage);
# Out:
# WARNING:raco.backends.myria.myria:Error converting Store(public:adhoc:garbage)[MyriaLimit(5)[Collect(@None)[MyriaLimit(5)[Scan(public:adhoc:cosmo8_000970)]]]]: convert <class 'raco.backends.myria.myria.MyriaLimit'> to sql
# WARNING:raco.backends.myria.myria:Error converting MyriaLimit(5)[Collect(@None)[MyriaLimit(5)[Scan(public:adhoc:cosmo8_000970)]]]: convert <class 'raco.backends.myria.myria.MyriaLimit'> to sql
# WARNING:raco.backends.myria.myria:Error converting Collect(@None)[MyriaLimit(5)[Scan(public:adhoc:cosmo8_000970)]]: convert <class 'raco.backends.myria.myria.MyriaLimit'> to sql
# WARNING:raco.backends.myria.myria:Error converting MyriaLimit(5)[Scan(public:adhoc:cosmo8_000970)]: convert <class 'raco.backends.myria.myria.MyriaLimit'> to sql
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>eps</th>
#       <th>grp</th>
#       <th>hsmooth</th>
#       <th>iOrder</th>
#       <th>mass</th>
#       <th>metals</th>
#       <th>phi</th>
#       <th>rho</th>
#       <th>temp</th>
#       <th>tform</th>
#       <th>type</th>
#       <th>vx</th>
#       <th>vy</th>
#       <th>vz</th>
#       <th>x</th>
#       <th>y</th>
#       <th>z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>3</td>
#       <td>2.875926e-09</td>
#       <td>0.000034</td>
#       <td>0.058942</td>
#       <td>1.123448</td>
#       <td>34840.890625</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>0.236078</td>
#       <td>0.035999</td>
#       <td>0.436954</td>
#       <td>-0.445655</td>
#       <td>0.485082</td>
#       <td>-0.437207</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.0</td>
#       <td>10</td>
#       <td>0.00004</td>
#       <td>7</td>
#       <td>2.944788e-09</td>
#       <td>0.000691</td>
#       <td>-0.017333</td>
#       <td>4.871498</td>
#       <td>150818.062500</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.847015</td>
#       <td>-0.406119</td>
#       <td>-0.155510</td>
#       <td>-0.447208</td>
#       <td>0.464690</td>
#       <td>-0.467272</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0</td>
#       <td>10</td>
#       <td>0.00004</td>
#       <td>11</td>
#       <td>2.506011e-09</td>
#       <td>0.026290</td>
#       <td>-0.434927</td>
#       <td>84844.773438</td>
#       <td>425098.406250</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>1.229649</td>
#       <td>0.513949</td>
#       <td>1.899611</td>
#       <td>-0.453420</td>
#       <td>0.463143</td>
#       <td>-0.470302</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0</td>
#       <td>10</td>
#       <td>0.00004</td>
#       <td>16</td>
#       <td>2.264056e-09</td>
#       <td>0.029570</td>
#       <td>-0.371879</td>
#       <td>40928.667969</td>
#       <td>9875.431641</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.200566</td>
#       <td>-1.031360</td>
#       <td>0.534631</td>
#       <td>-0.453803</td>
#       <td>0.463405</td>
#       <td>-0.470233</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0</td>
#       <td>10</td>
#       <td>0.00004</td>
#       <td>21</td>
#       <td>1.007631e-09</td>
#       <td>0.024677</td>
#       <td>-0.520269</td>
#       <td>86687.343750</td>
#       <td>363820.656250</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.566065</td>
#       <td>0.684031</td>
#       <td>0.669186</td>
#       <td>-0.453111</td>
#       <td>0.463671</td>
#       <td>-0.470319</td>
#     </tr>
#   </tbody>
# </table>

# %%
# %%query
# -- there are some built in functions that are useful, just like regular SQL:
# cosmo8 = scan(cosmo8_000970);
# countRows = select count(*) as countRows from cosmo8;
# store(countRows, garbage);
# Out:
# WARNING:raco.backends.myria.myria:Error converting Store(public:adhoc:garbage)[Apply(countRows=$0)[MyriaGroupBy(; SUM($0))[Collect(@None)[MyriaGroupBy(; COUNTALL)[Apply(iOrder=$0)[Scan(public:adhoc:cosmo8_000970)]]]]]]: convert <class 'raco.algebra.Collect'> to sql
# WARNING:raco.backends.myria.myria:Error converting Apply(countRows=$0)[MyriaGroupBy(; SUM($0))[Collect(@None)[MyriaGroupBy(; COUNTALL)[Apply(iOrder=$0)[Scan(public:adhoc:cosmo8_000970)]]]]]: convert <class 'raco.algebra.Collect'> to sql
# WARNING:raco.backends.myria.myria:Error converting MyriaGroupBy(; SUM($0))[Collect(@None)[MyriaGroupBy(; COUNTALL)[Apply(iOrder=$0)[Scan(public:adhoc:cosmo8_000970)]]]]: convert <class 'raco.algebra.Collect'> to sql
# WARNING:raco.backends.myria.myria:Error converting Collect(@None)[MyriaGroupBy(; COUNTALL)[Apply(iOrder=$0)[Scan(public:adhoc:cosmo8_000970)]]]: convert <class 'raco.algebra.Collect'> to sql
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>countRows</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>37027826</td>
#     </tr>
#   </tbody>
# </table>

# %%
# %%query
# -- lets say we want just the number of gas particles
# cosmo8 = scan(cosmo8_000970);
# c = select count(*) as numGas from cosmo8 where type = 'gas';
# store(c, garbage);
# Out:
# WARNING:raco.backends.myria.myria:Error converting Store(public:adhoc:garbage)[Apply(numGas=$0)[MyriaGroupBy(; SUM($0))[Collect(@None)[MyriaGroupBy(; COUNTALL)[Apply(iOrder=$0)[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000970)]]]]]]]: convert <class 'raco.algebra.Collect'> to sql
# WARNING:raco.backends.myria.myria:Error converting Apply(numGas=$0)[MyriaGroupBy(; SUM($0))[Collect(@None)[MyriaGroupBy(; COUNTALL)[Apply(iOrder=$0)[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000970)]]]]]]: convert <class 'raco.algebra.Collect'> to sql
# WARNING:raco.backends.myria.myria:Error converting MyriaGroupBy(; SUM($0))[Collect(@None)[MyriaGroupBy(; COUNTALL)[Apply(iOrder=$0)[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000970)]]]]]: convert <class 'raco.algebra.Collect'> to sql
# WARNING:raco.backends.myria.myria:Error converting Collect(@None)[MyriaGroupBy(; COUNTALL)[Apply(iOrder=$0)[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000970)]]]]: convert <class 'raco.algebra.Collect'> to sql
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>numGas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16248372</td>
#     </tr>
#   </tbody>
# </table>

# %%
# %%query
# -- some stats about the positions of star particles
# cosmo8 = scan(cosmo8_000970);
# positionStats = select min(x) as min_x
#         , max(x) as max_x
#         , avg(x) as avg_x
#         , stdev(x) as stdev_x
#         , min(y) as min_y
#         , max(y) as max_y
#         , avg(y) as avg_y
#         , stdev(y) as stdev_y
#         , min(z) as min_z
#         , max(z) as max_z
#         , avg(z) as avg_z
#         , stdev(z) as stdev_z
#     from cosmo8
#     where type = 'star';
# store(positionStats, garbage);
# Out:
# WARNING:raco.backends.myria.myria:Error converting Store(public:adhoc:garbage)[Apply(min_x=$0,max_x=$1,avg_x=($2 / $3),stdev_x=SQRT((($5 / $6) - POW(($4 / $6), 2))),min_y=$7,max_y=$8,avg_y=($9 / $10),stdev_y=SQRT((($12 / $13) - POW(($11 / $13), 2))),min_z=$14,max_z=$15,avg_z=($16 / $17),stdev_z=SQRT((($19 / $20) - POW(($18 / $20), 2))))[MyriaGroupBy(; MIN($0),MAX($1),SUM($2),SUM($3),SUM($4),SUM($5),SUM($6),MIN($7),MAX($8),SUM($9),SUM($10),SUM($11),SUM($12),SUM($13),MIN($14),MAX($15),SUM($16),SUM($17),SUM($18),SUM($19),SUM($20))[Collect(@None)[Apply(_COLUMN0_=$0,_COLUMN1_=$1,_COLUMN2_=$2,_COLUMN3_=$3,_COLUMN4_=$2,_COLUMN5_=$4,_COLUMN6_=$3,_COLUMN7_=$5,_COLUMN8_=$6,_COLUMN9_=$7,_COLUMN10_=$3,_COLUMN11_=$7,_COLUMN12_=$8,_COLUMN13_=$3,_COLUMN14_=$9,_COLUMN15_=$10,_COLUMN16_=$11,_COLUMN17_=$3,_COLUMN18_=$11,_COLUMN19_=$12,_COLUMN20_=$3)[MyriaGroupBy(; MIN($0),MAX($0),SUM($0),COUNTALL,SUM($3),MIN($1),MAX($1),SUM($1),SUM($4),MIN($2),MAX($2),SUM($2),SUM($5))[Apply(x=$2,y=$3,z=$4,_COLUMN3_=($2 * $2),_COLUMN4_=($3 * $3),_COLUMN5_=($4 * $4))[Select(($16 = "star"))[Scan(public:adhoc:cosmo8_000970)]]]]]]]]: expression <class 'raco.expression.expression.TIMES'> to sql
# WARNING:raco.backends.myria.myria:Error converting Apply(min_x=$0,max_x=$1,avg_x=($2 / $3),stdev_x=SQRT((($5 / $6) - POW(($4 / $6), 2))),min_y=$7,max_y=$8,avg_y=($9 / $10),stdev_y=SQRT((($12 / $13) - POW(($11 / $13), 2))),min_z=$14,max_z=$15,avg_z=($16 / $17),stdev_z=SQRT((($19 / $20) - POW(($18 / $20), 2))))[MyriaGroupBy(; MIN($0),MAX($1),SUM($2),SUM($3),SUM($4),SUM($5),SUM($6),MIN($7),MAX($8),SUM($9),SUM($10),SUM($11),SUM($12),SUM($13),MIN($14),MAX($15),SUM($16),SUM($17),SUM($18),SUM($19),SUM($20))[Collect(@None)[Apply(_COLUMN0_=$0,_COLUMN1_=$1,_COLUMN2_=$2,_COLUMN3_=$3,_COLUMN4_=$2,_COLUMN5_=$4,_COLUMN6_=$3,_COLUMN7_=$5,_COLUMN8_=$6,_COLUMN9_=$7,_COLUMN10_=$3,_COLUMN11_=$7,_COLUMN12_=$8,_COLUMN13_=$3,_COLUMN14_=$9,_COLUMN15_=$10,_COLUMN16_=$11,_COLUMN17_=$3,_COLUMN18_=$11,_COLUMN19_=$12,_COLUMN20_=$3)[MyriaGroupBy(; MIN($0),MAX($0),SUM($0),COUNTALL,SUM($3),MIN($1),MAX($1),SUM($1),SUM($4),MIN($2),MAX($2),SUM($2),SUM($5))[Apply(x=$2,y=$3,z=$4,_COLUMN3_=($2 * $2),_COLUMN4_=($3 * $3),_COLUMN5_=($4 * $4))[Select(($16 = "star"))[Scan(public:adhoc:cosmo8_000970)]]]]]]]: expression <class 'raco.expression.expression.TIMES'> to sql
# WARNING:raco.backends.myria.myria:Error converting MyriaGroupBy(; MIN($0),MAX($1),SUM($2),SUM($3),SUM($4),SUM($5),SUM($6),MIN($7),MAX($8),SUM($9),SUM($10),SUM($11),SUM($12),SUM($13),MIN($14),MAX($15),SUM($16),SUM($17),SUM($18),SUM($19),SUM($20))[Collect(@None)[Apply(_COLUMN0_=$0,_COLUMN1_=$1,_COLUMN2_=$2,_COLUMN3_=$3,_COLUMN4_=$2,_COLUMN5_=$4,_COLUMN6_=$3,_COLUMN7_=$5,_COLUMN8_=$6,_COLUMN9_=$7,_COLUMN10_=$3,_COLUMN11_=$7,_COLUMN12_=$8,_COLUMN13_=$3,_COLUMN14_=$9,_COLUMN15_=$10,_COLUMN16_=$11,_COLUMN17_=$3,_COLUMN18_=$11,_COLUMN19_=$12,_COLUMN20_=$3)[MyriaGroupBy(; MIN($0),MAX($0),SUM($0),COUNTALL,SUM($3),MIN($1),MAX($1),SUM($1),SUM($4),MIN($2),MAX($2),SUM($2),SUM($5))[Apply(x=$2,y=$3,z=$4,_COLUMN3_=($2 * $2),_COLUMN4_=($3 * $3),_COLUMN5_=($4 * $4))[Select(($16 = "star"))[Scan(public:adhoc:cosmo8_000970)]]]]]]: expression <class 'raco.expression.expression.TIMES'> to sql
# WARNING:raco.backends.myria.myria:Error converting Collect(@None)[Apply(_COLUMN0_=$0,_COLUMN1_=$1,_COLUMN2_=$2,_COLUMN3_=$3,_COLUMN4_=$2,_COLUMN5_=$4,_COLUMN6_=$3,_COLUMN7_=$5,_COLUMN8_=$6,_COLUMN9_=$7,_COLUMN10_=$3,_COLUMN11_=$7,_COLUMN12_=$8,_COLUMN13_=$3,_COLUMN14_=$9,_COLUMN15_=$10,_COLUMN16_=$11,_COLUMN17_=$3,_COLUMN18_=$11,_COLUMN19_=$12,_COLUMN20_=$3)[MyriaGroupBy(; MIN($0),MAX($0),SUM($0),COUNTALL,SUM($3),MIN($1),MAX($1),SUM($1),SUM($4),MIN($2),MAX($2),SUM($2),SUM($5))[Apply(x=$2,y=$3,z=$4,_COLUMN3_=($2 * $2),_COLUMN4_=($3 * $3),_COLUMN5_=($4 * $4))[Select(($16 = "star"))[Scan(public:adhoc:cosmo8_000970)]]]]]: expression <class 'raco.expression.expression.TIMES'> to sql
# WARNING:raco.backends.myria.myria:Error converting Apply(_COLUMN0_=$0,_COLUMN1_=$1,_COLUMN2_=$2,_COLUMN3_=$3,_COLUMN4_=$2,_COLUMN5_=$4,_COLUMN6_=$3,_COLUMN7_=$5,_COLUMN8_=$6,_COLUMN9_=$7,_COLUMN10_=$3,_COLUMN11_=$7,_COLUMN12_=$8,_COLUMN13_=$3,_COLUMN14_=$9,_COLUMN15_=$10,_COLUMN16_=$11,_COLUMN17_=$3,_COLUMN18_=$11,_COLUMN19_=$12,_COLUMN20_=$3)[MyriaGroupBy(; MIN($0),MAX($0),SUM($0),COUNTALL,SUM($3),MIN($1),MAX($1),SUM($1),SUM($4),MIN($2),MAX($2),SUM($2),SUM($5))[Apply(x=$2,y=$3,z=$4,_COLUMN3_=($2 * $2),_COLUMN4_=($3 * $3),_COLUMN5_=($4 * $4))[Select(($16 = "star"))[Scan(public:adhoc:cosmo8_000970)]]]]: expression <class 'raco.expression.expression.TIMES'> to sql
# WARNING:raco.backends.myria.myria:Error converting MyriaGroupBy(; MIN($0),MAX($0),SUM($0),COUNTALL,SUM($3),MIN($1),MAX($1),SUM($1),SUM($4),MIN($2),MAX($2),SUM($2),SUM($5))[Apply(x=$2,y=$3,z=$4,_COLUMN3_=($2 * $2),_COLUMN4_=($3 * $3),_COLUMN5_=($4 * $4))[Select(($16 = "star"))[Scan(public:adhoc:cosmo8_000970)]]]: expression <class 'raco.expression.expression.TIMES'> to sql
# WARNING:raco.backends.myria.myria:Error converting Apply(x=$2,y=$3,z=$4,_COLUMN3_=($2 * $2),_COLUMN4_=($3 * $3),_COLUMN5_=($4 * $4))[Select(($16 = "star"))[Scan(public:adhoc:cosmo8_000970)]]: expression <class 'raco.expression.expression.TIMES'> to sql
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>avg_x</th>
#       <th>avg_y</th>
#       <th>avg_z</th>
#       <th>max_x</th>
#       <th>max_y</th>
#       <th>max_z</th>
#       <th>min_x</th>
#       <th>min_y</th>
#       <th>min_z</th>
#       <th>stdev_x</th>
#       <th>stdev_y</th>
#       <th>stdev_z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-0.019366</td>
#       <td>0.257192</td>
#       <td>0.047189</td>
#       <td>0.499978</td>
#       <td>0.5</td>
#       <td>0.499979</td>
#       <td>-0.498746</td>
#       <td>-0.499999</td>
#       <td>-0.499799</td>
#       <td>0.288936</td>
#       <td>0.198463</td>
#       <td>0.294115</td>
#     </tr>
#   </tbody>
# </table>

# %%
# we can also create constants in Python and reference them in MyriaL
low = 50000
high = 100000
destination = 'tempRangeCosmo8'

# %%
# %%query
# -- we can reference Python constants with '@'
# cosmo8 = scan(cosmo8_000970);
# temps = select iOrder, mass, type, temp
#     from cosmo8
#     where temp > @low and temp < @high
#     limit 10;
#
# store(temps, @destination);
# Out:
# WARNING:raco.backends.myria.myria:Error converting Store(public:adhoc:tempRangeCosmo8)[MyriaLimit(10)[Collect(@None)[MyriaLimit(10)[Apply(iOrder=iOrder,mass=mass,type=type,temp=temp)[Select((($9 > 50000) and ($9 < 100000)))[Scan(public:adhoc:cosmo8_000970)]]]]]]: convert <class 'raco.backends.myria.myria.MyriaLimit'> to sql
# WARNING:raco.backends.myria.myria:Error converting MyriaLimit(10)[Collect(@None)[MyriaLimit(10)[Apply(iOrder=iOrder,mass=mass,type=type,temp=temp)[Select((($9 > 50000) and ($9 < 100000)))[Scan(public:adhoc:cosmo8_000970)]]]]]: convert <class 'raco.backends.myria.myria.MyriaLimit'> to sql
# WARNING:raco.backends.myria.myria:Error converting Collect(@None)[MyriaLimit(10)[Apply(iOrder=iOrder,mass=mass,type=type,temp=temp)[Select((($9 > 50000) and ($9 < 100000)))[Scan(public:adhoc:cosmo8_000970)]]]]: convert <class 'raco.backends.myria.myria.MyriaLimit'> to sql
# WARNING:raco.backends.myria.myria:Error converting MyriaLimit(10)[Apply(iOrder=iOrder,mass=mass,type=type,temp=temp)[Select((($9 > 50000) and ($9 < 100000)))[Scan(public:adhoc:cosmo8_000970)]]]: convert <class 'raco.backends.myria.myria.MyriaLimit'> to sql
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>iOrder</th>
#       <th>mass</th>
#       <th>temp</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>38505</td>
#       <td>2.875926e-09</td>
#       <td>54099.609375</td>
#       <td>gas</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>38509</td>
#       <td>2.875926e-09</td>
#       <td>94639.531250</td>
#       <td>gas</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>38513</td>
#       <td>2.875926e-09</td>
#       <td>67370.273438</td>
#       <td>gas</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>38757</td>
#       <td>2.875926e-09</td>
#       <td>64836.183594</td>
#       <td>gas</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>38761</td>
#       <td>2.875926e-09</td>
#       <td>52559.175781</td>
#       <td>gas</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>38769</td>
#       <td>2.875926e-09</td>
#       <td>65664.242188</td>
#       <td>gas</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>38805</td>
#       <td>2.924718e-09</td>
#       <td>53748.503906</td>
#       <td>gas</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>39013</td>
#       <td>2.875926e-09</td>
#       <td>54492.980469</td>
#       <td>gas</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>39029</td>
#       <td>2.875926e-09</td>
#       <td>52489.531250</td>
#       <td>gas</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>39269</td>
#       <td>2.875926e-09</td>
#       <td>67958.992188</td>
#       <td>gas</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## User Defined Functions

# %% [markdown]
# In MyriaL we can define our own functions that will then be applied to the results of a query. These can either be written in Python and registered with Myria or they can be written directly within a MyriaL cell (but not in Python).
#
# When registering a Python function as a UDF, we need to specify the type of the return value. The possible types are the `INTERNAL_TYPES` defined in `raco.types` <a href="https://github.com/uwescience/raco/blob/4b2387aaaa82daaeac6c8960c837a6ccc7d46ff8/raco/types.py">as seen here</a>
#
# Currently a function signature can't be registered more than once. In order to overwrite an existing registered function of the same signature, you have to use the Restart Kernel button in the Jupyter Notebook toolbar.

# %%
from raco.types import DOUBLE_TYPE
from myria.udf import MyriaPythonFunction

# each row is passed in as a tupl within a list
def sillyUDF(tuplList):
    row = tuplList[0]
    x = row[0]
    y = row[1]
    z = row[2]
        
    if (x > y):
        return x + y + z
    else:
        return z

# A python function needs to be registered to be able to 
# call it from a MyriaL cell
MyriaPythonFunction(sillyUDF, DOUBLE_TYPE).register()
# Out:
# DuplicateFunctionDefinitionExceptionTraceback (most recent call last)
# <ipython-input-8-e0f8708ced01> in <module>()
#      16 # A python function needs to be registered to be able to
#      17 # call it from a MyriaL cell
# ---> 18 MyriaPythonFunction(sillyUDF, DOUBLE_TYPE).register()
#
# /usr/local/lib/python2.7/dist-packages/myria_python-1.3.1-py2.7.egg/myria/udf.pyc in register(self)
#      66         connection = self.connection or MyriaRelation.DefaultConnection
#      67         self.get_all(connection).append(self)
# ---> 68         connection.create_function(self.to_dict())
#      69
#      70     def to_dict(self):
#
# /usr/local/lib/python2.7/dist-packages/myria_python-1.3.1-py2.7.egg/myria/connection.pyc in create_function(self, d, overwrite_if_exists)
#     271             rest_url=self._url_start,
#     272             execution_url=self.execution_url).create_function(
# --> 273             d, overwrite_if_exists=overwrite_if_exists)
#     274
#     275     def get_functions(self):
#
# /usr/local/lib/python2.7/dist-packages/raco-1.3.5-py2.7.egg/raco/backends/myria/connection.pyc in create_function(self, d, overwrite_if_exists)
#     501         result = self._make_request(POST, '/function', json.dumps(d))
#     502         Parser.add_python_udf(d.pop('name'), d.pop('outputType'),
# --> 503                               overwrite_if_exists=overwrite_if_exists, **d)
#     504         return result
#     505
#
# /usr/local/lib/python2.7/dist-packages/raco-1.3.5-py2.7.egg/raco/myrial/parser.pyc in add_python_udf(name, typ, **kwargs)
#     299         """
#     300         if name in Parser.udf_functions:
# --> 301             raise DuplicateFunctionDefinitionException(name, -1)
#     302
#     303         f = VariadicFunction(PYUDF, name, typ, **kwargs)
#
# DuplicateFunctionDefinitionException: Duplicate function definition for sillyUDF on line -1

# %%
# To see all functions currently registered
connection.get_functions()
# Out:
# [u'argMax',
#  u'distance',
#  u'maxValue',
#  u'pickBasedOnValue',
#  u'pyIsPrime',
#  u'silly10',
#  u'silly11',
#  u'silly12',
#  u'silly13',
#  u'silly2',
#  u'silly3',
#  u'silly4',
#  u'silly5',
#  u'silly8',
#  u'silly9',
#  u'sillyFunction',
#  u'sillyUDF',
#  u'udfAgg',
#  u'udfSum']

# %%
# %%query
# -- for your queries to run faster, its better to push the UDF to the smallest possible set of data
# cosmo8 = scan(cosmo8_000970);
# small = select * from cosmo8 limit 10;
# res = select sillyUDF(x,y,z) as sillyPyRes from small;
# store(res, garbage);
# Out:
# WARNING:raco.backends.myria.myria:Error converting Store(public:adhoc:garbage)[Apply(sillyPyRes=PYUDF(sillyUDF, ['x', 'y', 'z'], DOUBLE_TYPE))[MyriaLimit(10)[Collect(@None)[MyriaLimit(10)[Scan(public:adhoc:cosmo8_000970)]]]]]: convert <class 'raco.backends.myria.myria.MyriaLimit'> to sql
# WARNING:raco.backends.myria.myria:Error converting Apply(sillyPyRes=PYUDF(sillyUDF, ['x', 'y', 'z'], DOUBLE_TYPE))[MyriaLimit(10)[Collect(@None)[MyriaLimit(10)[Scan(public:adhoc:cosmo8_000970)]]]]: convert <class 'raco.backends.myria.myria.MyriaLimit'> to sql
# WARNING:raco.backends.myria.myria:Error converting MyriaLimit(10)[Collect(@None)[MyriaLimit(10)[Scan(public:adhoc:cosmo8_000970)]]]: convert <class 'raco.backends.myria.myria.MyriaLimit'> to sql
# WARNING:raco.backends.myria.myria:Error converting Collect(@None)[MyriaLimit(10)[Scan(public:adhoc:cosmo8_000970)]]: convert <class 'raco.backends.myria.myria.MyriaLimit'> to sql
# WARNING:raco.backends.myria.myria:Error converting MyriaLimit(10)[Scan(public:adhoc:cosmo8_000970)]: convert <class 'raco.backends.myria.myria.MyriaLimit'> to sql
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sillyPyRes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-0.041094</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-0.041389</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-0.041020</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.041744</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.041161</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>-0.039189</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.788064</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-0.154662</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.156610</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>-0.996438</td>
#     </tr>
#   </tbody>
# </table>

# %%
# %%query
# -- same thing but as a MyriaL UDF
# def silly(x,y,z):
#     case
#         when x > y
#         then x + y + z
#         else z
#     end;
#
# cosmo8 = scan(cosmo8_000970);
# res = select silly(x,y,z) as sillyMyRes from cosmo8 limit 10;
# store(res, garbage);
# Out:
# WARNING:raco.backends.myria.myria:Error converting Store(public:adhoc:garbage)[MyriaLimit(10)[Collect(@None)[MyriaLimit(10)[Apply(sillyMyRes=CASE(WHEN ($2 > $3) THEN (($2 + $3) + $4) ELSE $4))[Scan(public:adhoc:cosmo8_000970)]]]]]: expression <class 'raco.expression.expression.PLUS'> to sql
# WARNING:raco.backends.myria.myria:Error converting MyriaLimit(10)[Collect(@None)[MyriaLimit(10)[Apply(sillyMyRes=CASE(WHEN ($2 > $3) THEN (($2 + $3) + $4) ELSE $4))[Scan(public:adhoc:cosmo8_000970)]]]]: expression <class 'raco.expression.expression.PLUS'> to sql
# WARNING:raco.backends.myria.myria:Error converting Collect(@None)[MyriaLimit(10)[Apply(sillyMyRes=CASE(WHEN ($2 > $3) THEN (($2 + $3) + $4) ELSE $4))[Scan(public:adhoc:cosmo8_000970)]]]: expression <class 'raco.expression.expression.PLUS'> to sql
# WARNING:raco.backends.myria.myria:Error converting MyriaLimit(10)[Apply(sillyMyRes=CASE(WHEN ($2 > $3) THEN (($2 + $3) + $4) ELSE $4))[Scan(public:adhoc:cosmo8_000970)]]: expression <class 'raco.expression.expression.PLUS'> to sql
# WARNING:raco.backends.myria.myria:Error converting Apply(sillyMyRes=CASE(WHEN ($2 > $3) THEN (($2 + $3) + $4) ELSE $4))[Scan(public:adhoc:cosmo8_000970)]: expression <class 'raco.expression.expression.PLUS'> to sql
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sillyMyRes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.237824</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.258984</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.292571</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.322751</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.349662</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.378418</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.394452</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-0.577188</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.561296</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>-0.544281</td>
#     </tr>
#   </tbody>
# </table>

# %%
from raco.types import DOUBLE_TYPE

def distance(tuplList):
    # note that libraries used inside the UDF need to be imported inside the UDF
    import math
    row = tuplList[0]
    x1 = row[0]
    y1 = row[1]
    z1 = row[2]
    x2 = row[3]
    y2 = row[4]
    z2 = row[5]
    
    return math.sqrt((x1-x2)**2 + (y1-y2)**2 + (z1-z2)**2)

MyriaPythonFunction(distance, DOUBLE_TYPE).register()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-3-905191a634c4> in <module>()
#      14     return math.sqrt((x1-x2)**2 + (y1-y2)**2 + (z1-z2)**2)
#      15
# ---> 16 MyriaPythonFunction(distance, DOUBLE_TYPE).register()
#
# NameError: name 'MyriaPythonFunction' is not defined

# %%
print distance([(.1, .1, .1, .2, .2, .2)])
# Out:
# 0.173205080757

# %%
eps = .0042

# %%
# %%query
# -- here I am trying to find all points within eps distance of a given point
# -- in order to avoid the expensive UDF distance() call on every point in the data,
# -- I first filter the points by a simpler range query that immitates a bounding box
# cosmo8 = scan(cosmo8_000970);
# point = select * from cosmo8 where iOrder = 68649;
# cube = select c.* from cosmo8 as c, point as p
#     where abs(c.x - p.x) < @eps
#     and abs(c.y - p.y) < @eps
#     and abs(c.z - p.z) < @eps;
# distances = select c.*, distance(c.x, c.y, c.z, p.x, p.y, p.z) as dist from cube as c, point as p;
# res = select * from distances where dist < @eps;
# store(res, garbage);
# Out:
# WARNING:raco.backends.myria.myria:Error converting Store(public:adhoc:garbage)[Select(($17 < 0.0042))[Apply(iOrder=iOrder,mass=mass,x=x,y=y,z=z,vx=vx,vy=vy,vz=vz,rho=rho,temp=temp,hsmooth=hsmooth,metals=metals,tform=tform,eps=eps,phi=phi,grp=grp,type=type,dist=PYUDF(distance, ['x', 'y', 'z', 'x', 'y', 'z'], DOUBLE_TYPE))[CrossProduct[Apply(iOrder=iOrder,mass=mass,x=x,y=y,z=z,vx=vx,vy=vy,vz=vz,rho=rho,temp=temp,hsmooth=hsmooth,metals=metals,tform=tform,eps=eps,phi=phi,grp=grp,type=type)[Select((((ABS((x - x)) < 0.0042) and (ABS((y - y)) < 0.0042)) and (ABS((z - z)) < 0.0042)))[CrossProduct[Scan(public:adhoc:cosmo8_000970),Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]],Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]]]: convert <class 'raco.algebra.Broadcast'> to sql
# WARNING:raco.backends.myria.myria:Error converting Select(($17 < 0.0042))[Apply(iOrder=iOrder,mass=mass,x=x,y=y,z=z,vx=vx,vy=vy,vz=vz,rho=rho,temp=temp,hsmooth=hsmooth,metals=metals,tform=tform,eps=eps,phi=phi,grp=grp,type=type,dist=PYUDF(distance, ['x', 'y', 'z', 'x', 'y', 'z'], DOUBLE_TYPE))[CrossProduct[Apply(iOrder=iOrder,mass=mass,x=x,y=y,z=z,vx=vx,vy=vy,vz=vz,rho=rho,temp=temp,hsmooth=hsmooth,metals=metals,tform=tform,eps=eps,phi=phi,grp=grp,type=type)[Select((((ABS((x - x)) < 0.0042) and (ABS((y - y)) < 0.0042)) and (ABS((z - z)) < 0.0042)))[CrossProduct[Scan(public:adhoc:cosmo8_000970),Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]],Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]]: convert <class 'raco.algebra.Broadcast'> to sql
# WARNING:raco.backends.myria.myria:Error converting Apply(iOrder=iOrder,mass=mass,x=x,y=y,z=z,vx=vx,vy=vy,vz=vz,rho=rho,temp=temp,hsmooth=hsmooth,metals=metals,tform=tform,eps=eps,phi=phi,grp=grp,type=type,dist=PYUDF(distance, ['x', 'y', 'z', 'x', 'y', 'z'], DOUBLE_TYPE))[CrossProduct[Apply(iOrder=iOrder,mass=mass,x=x,y=y,z=z,vx=vx,vy=vy,vz=vz,rho=rho,temp=temp,hsmooth=hsmooth,metals=metals,tform=tform,eps=eps,phi=phi,grp=grp,type=type)[Select((((ABS((x - x)) < 0.0042) and (ABS((y - y)) < 0.0042)) and (ABS((z - z)) < 0.0042)))[CrossProduct[Scan(public:adhoc:cosmo8_000970),Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]],Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]: convert <class 'raco.algebra.Broadcast'> to sql
# WARNING:raco.backends.myria.myria:Error converting CrossProduct[Apply(iOrder=iOrder,mass=mass,x=x,y=y,z=z,vx=vx,vy=vy,vz=vz,rho=rho,temp=temp,hsmooth=hsmooth,metals=metals,tform=tform,eps=eps,phi=phi,grp=grp,type=type)[Select((((ABS((x - x)) < 0.0042) and (ABS((y - y)) < 0.0042)) and (ABS((z - z)) < 0.0042)))[CrossProduct[Scan(public:adhoc:cosmo8_000970),Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]],Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]: convert <class 'raco.algebra.Broadcast'> to sql
# WARNING:raco.backends.myria.myria:Error converting Apply(iOrder=iOrder,mass=mass,x=x,y=y,z=z,vx=vx,vy=vy,vz=vz,rho=rho,temp=temp,hsmooth=hsmooth,metals=metals,tform=tform,eps=eps,phi=phi,grp=grp,type=type)[Select((((ABS((x - x)) < 0.0042) and (ABS((y - y)) < 0.0042)) and (ABS((z - z)) < 0.0042)))[CrossProduct[Scan(public:adhoc:cosmo8_000970),Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]]: convert <class 'raco.algebra.Broadcast'> to sql
# WARNING:raco.backends.myria.myria:Error converting Select((((ABS((x - x)) < 0.0042) and (ABS((y - y)) < 0.0042)) and (ABS((z - z)) < 0.0042)))[CrossProduct[Scan(public:adhoc:cosmo8_000970),Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]: convert <class 'raco.algebra.Broadcast'> to sql
# WARNING:raco.backends.myria.myria:Error converting CrossProduct[Scan(public:adhoc:cosmo8_000970),Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]: convert <class 'raco.algebra.Broadcast'> to sql
# WARNING:raco.backends.myria.myria:Error converting Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]: convert <class 'raco.algebra.Broadcast'> to sql
# WARNING:raco.backends.myria.myria:Error converting Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]: convert <class 'raco.algebra.Broadcast'> to sql
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dist</th>
#       <th>eps</th>
#       <th>grp</th>
#       <th>hsmooth</th>
#       <th>iOrder</th>
#       <th>mass</th>
#       <th>metals</th>
#       <th>phi</th>
#       <th>rho</th>
#       <th>temp</th>
#       <th>tform</th>
#       <th>type</th>
#       <th>vx</th>
#       <th>vy</th>
#       <th>vz</th>
#       <th>x</th>
#       <th>y</th>
#       <th>z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.003900</td>
#       <td>0.00004</td>
#       <td>0</td>
#       <td>0.00000</td>
#       <td>33423611</td>
#       <td>1.551807e-08</td>
#       <td>0.000000e+00</td>
#       <td>0.056556</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.0</td>
#       <td>dark</td>
#       <td>0.666898</td>
#       <td>-0.071780</td>
#       <td>0.679524</td>
#       <td>-0.433200</td>
#       <td>0.479377</td>
#       <td>-0.430269</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.004125</td>
#       <td>0.00004</td>
#       <td>0</td>
#       <td>0.00000</td>
#       <td>33423867</td>
#       <td>1.551807e-08</td>
#       <td>0.000000e+00</td>
#       <td>0.057097</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.0</td>
#       <td>dark</td>
#       <td>0.781923</td>
#       <td>-0.088264</td>
#       <td>0.735718</td>
#       <td>-0.430704</td>
#       <td>0.477364</td>
#       <td>-0.428336</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.000000</td>
#       <td>0.00000</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>68649</td>
#       <td>2.875926e-09</td>
#       <td>3.064064e-06</td>
#       <td>0.059639</td>
#       <td>0.317765</td>
#       <td>54363.511719</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.501991</td>
#       <td>-0.283368</td>
#       <td>0.436636</td>
#       <td>-0.429473</td>
#       <td>0.480128</td>
#       <td>-0.431140</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.001790</td>
#       <td>0.00000</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>198697</td>
#       <td>2.875926e-09</td>
#       <td>7.456512e-07</td>
#       <td>0.060503</td>
#       <td>0.312199</td>
#       <td>51896.492188</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.562210</td>
#       <td>-0.210162</td>
#       <td>0.467729</td>
#       <td>-0.428072</td>
#       <td>0.479019</td>
#       <td>-0.431236</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.003808</td>
#       <td>0.00000</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>264232</td>
#       <td>2.875926e-09</td>
#       <td>6.369171e-06</td>
#       <td>0.058350</td>
#       <td>0.391214</td>
#       <td>67013.945312</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.384588</td>
#       <td>-0.146776</td>
#       <td>0.241331</td>
#       <td>-0.430473</td>
#       <td>0.483409</td>
#       <td>-0.429486</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.001326</td>
#       <td>0.00000</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>329256</td>
#       <td>2.875926e-09</td>
#       <td>1.571942e-05</td>
#       <td>0.059600</td>
#       <td>0.295852</td>
#       <td>84019.289062</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.352334</td>
#       <td>-0.130692</td>
#       <td>0.281435</td>
#       <td>-0.428558</td>
#       <td>0.480234</td>
#       <td>-0.430186</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.003718</td>
#       <td>0.00000</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>393255</td>
#       <td>2.875926e-09</td>
#       <td>6.654522e-06</td>
#       <td>0.057903</td>
#       <td>0.281416</td>
#       <td>93928.875000</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>0.050872</td>
#       <td>0.061671</td>
#       <td>0.864590</td>
#       <td>-0.429548</td>
#       <td>0.477498</td>
#       <td>-0.428513</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.003960</td>
#       <td>0.00000</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>393767</td>
#       <td>2.875926e-09</td>
#       <td>1.051521e-05</td>
#       <td>0.059647</td>
#       <td>0.326737</td>
#       <td>124846.312500</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.193425</td>
#       <td>-0.378229</td>
#       <td>0.444603</td>
#       <td>-0.427381</td>
#       <td>0.477410</td>
#       <td>-0.429161</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.004096</td>
#       <td>0.00000</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>394536</td>
#       <td>2.875926e-09</td>
#       <td>1.741445e-06</td>
#       <td>0.059991</td>
#       <td>0.248017</td>
#       <td>71934.960938</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.209395</td>
#       <td>-0.173627</td>
#       <td>0.030740</td>
#       <td>-0.426225</td>
#       <td>0.480099</td>
#       <td>-0.428645</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.004149</td>
#       <td>0.00000</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>395042</td>
#       <td>2.875926e-09</td>
#       <td>6.674573e-05</td>
#       <td>0.057279</td>
#       <td>0.308838</td>
#       <td>137163.468750</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>0.333954</td>
#       <td>-0.037838</td>
#       <td>0.548944</td>
#       <td>-0.428941</td>
#       <td>0.479095</td>
#       <td>-0.427157</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0.003289</td>
#       <td>0.00000</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>458790</td>
#       <td>2.875926e-09</td>
#       <td>5.269781e-05</td>
#       <td>0.056594</td>
#       <td>0.380030</td>
#       <td>109443.015625</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>0.170803</td>
#       <td>-0.170126</td>
#       <td>0.497237</td>
#       <td>-0.431394</td>
#       <td>0.480042</td>
#       <td>-0.428472</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>0.002882</td>
#       <td>0.00000</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>524070</td>
#       <td>2.875926e-09</td>
#       <td>3.222473e-05</td>
#       <td>0.057474</td>
#       <td>0.367752</td>
#       <td>125318.757812</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.119682</td>
#       <td>0.036516</td>
#       <td>0.611618</td>
#       <td>-0.431963</td>
#       <td>0.478853</td>
#       <td>-0.430446</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>0.003251</td>
#       <td>0.00000</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>780821</td>
#       <td>2.086354e-09</td>
#       <td>1.060728e-03</td>
#       <td>0.056983</td>
#       <td>0.325981</td>
#       <td>379442.312500</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.088490</td>
#       <td>-0.018165</td>
#       <td>0.311252</td>
#       <td>-0.430864</td>
#       <td>0.481299</td>
#       <td>-0.428445</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>0.002591</td>
#       <td>0.00000</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>16323624</td>
#       <td>2.875926e-09</td>
#       <td>3.965785e-07</td>
#       <td>0.060823</td>
#       <td>0.262628</td>
#       <td>52022.566406</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.523413</td>
#       <td>-0.382426</td>
#       <td>0.395408</td>
#       <td>-0.430112</td>
#       <td>0.481489</td>
#       <td>-0.433250</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>0.003962</td>
#       <td>0.00000</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>16650281</td>
#       <td>2.875926e-09</td>
#       <td>1.143463e-06</td>
#       <td>0.058384</td>
#       <td>0.396397</td>
#       <td>71281.289062</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.713831</td>
#       <td>-0.097779</td>
#       <td>0.476638</td>
#       <td>-0.432521</td>
#       <td>0.482611</td>
#       <td>-0.431628</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>0.003052</td>
#       <td>0.00000</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>16715050</td>
#       <td>2.875926e-09</td>
#       <td>4.304838e-08</td>
#       <td>0.062091</td>
#       <td>0.204497</td>
#       <td>29993.513672</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.719951</td>
#       <td>-0.331257</td>
#       <td>0.624576</td>
#       <td>-0.426765</td>
#       <td>0.479531</td>
#       <td>-0.432414</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>0.002909</td>
#       <td>0.00004</td>
#       <td>0</td>
#       <td>0.000

# %%
# %%query
# cosmo8 = scan(cosmo8_000970);
# point = select * from cosmo8 where iOrder = 68649;
# cube = select c.* from cosmo8 as c, point as p
#     where abs(c.x - p.x) < @eps
#     and abs(c.y - p.y) < @eps
#     and abs(c.z - p.z) < @eps;
# onlyGases = select * from cube where type = 'gas';
# distances = select c.*, distance(c.x, c.y, c.z, p.x, p.y, p.z) as dist from onlyGases as c, point as p;
# res = select * from distances where dist < @eps;
# store(res, garbage);
# Out:
# WARNING:raco.backends.myria.myria:Error converting Store(public:adhoc:garbage)[Select(($17 < 0.0042))[Apply(iOrder=iOrder,mass=mass,x=x,y=y,z=z,vx=vx,vy=vy,vz=vz,rho=rho,temp=temp,hsmooth=hsmooth,metals=metals,tform=tform,eps=eps,phi=phi,grp=grp,type=type,dist=PYUDF(distance, ['x', 'y', 'z', 'x', 'y', 'z'], DOUBLE_TYPE))[CrossProduct[Apply(iOrder=iOrder,mass=mass,x=x,y=y,z=z,vx=vx,vy=vy,vz=vz,rho=rho,temp=temp,hsmooth=hsmooth,metals=metals,tform=tform,eps=eps,phi=phi,grp=grp,type=type)[Select((((ABS((x - x)) < 0.0042) and (ABS((y - y)) < 0.0042)) and (ABS((z - z)) < 0.0042)))[CrossProduct[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000970)],Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]],Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]]]: convert <class 'raco.algebra.Broadcast'> to sql
# WARNING:raco.backends.myria.myria:Error converting Select(($17 < 0.0042))[Apply(iOrder=iOrder,mass=mass,x=x,y=y,z=z,vx=vx,vy=vy,vz=vz,rho=rho,temp=temp,hsmooth=hsmooth,metals=metals,tform=tform,eps=eps,phi=phi,grp=grp,type=type,dist=PYUDF(distance, ['x', 'y', 'z', 'x', 'y', 'z'], DOUBLE_TYPE))[CrossProduct[Apply(iOrder=iOrder,mass=mass,x=x,y=y,z=z,vx=vx,vy=vy,vz=vz,rho=rho,temp=temp,hsmooth=hsmooth,metals=metals,tform=tform,eps=eps,phi=phi,grp=grp,type=type)[Select((((ABS((x - x)) < 0.0042) and (ABS((y - y)) < 0.0042)) and (ABS((z - z)) < 0.0042)))[CrossProduct[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000970)],Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]],Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]]: convert <class 'raco.algebra.Broadcast'> to sql
# WARNING:raco.backends.myria.myria:Error converting Apply(iOrder=iOrder,mass=mass,x=x,y=y,z=z,vx=vx,vy=vy,vz=vz,rho=rho,temp=temp,hsmooth=hsmooth,metals=metals,tform=tform,eps=eps,phi=phi,grp=grp,type=type,dist=PYUDF(distance, ['x', 'y', 'z', 'x', 'y', 'z'], DOUBLE_TYPE))[CrossProduct[Apply(iOrder=iOrder,mass=mass,x=x,y=y,z=z,vx=vx,vy=vy,vz=vz,rho=rho,temp=temp,hsmooth=hsmooth,metals=metals,tform=tform,eps=eps,phi=phi,grp=grp,type=type)[Select((((ABS((x - x)) < 0.0042) and (ABS((y - y)) < 0.0042)) and (ABS((z - z)) < 0.0042)))[CrossProduct[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000970)],Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]],Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]: convert <class 'raco.algebra.Broadcast'> to sql
# WARNING:raco.backends.myria.myria:Error converting CrossProduct[Apply(iOrder=iOrder,mass=mass,x=x,y=y,z=z,vx=vx,vy=vy,vz=vz,rho=rho,temp=temp,hsmooth=hsmooth,metals=metals,tform=tform,eps=eps,phi=phi,grp=grp,type=type)[Select((((ABS((x - x)) < 0.0042) and (ABS((y - y)) < 0.0042)) and (ABS((z - z)) < 0.0042)))[CrossProduct[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000970)],Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]],Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]: convert <class 'raco.algebra.Broadcast'> to sql
# WARNING:raco.backends.myria.myria:Error converting Apply(iOrder=iOrder,mass=mass,x=x,y=y,z=z,vx=vx,vy=vy,vz=vz,rho=rho,temp=temp,hsmooth=hsmooth,metals=metals,tform=tform,eps=eps,phi=phi,grp=grp,type=type)[Select((((ABS((x - x)) < 0.0042) and (ABS((y - y)) < 0.0042)) and (ABS((z - z)) < 0.0042)))[CrossProduct[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000970)],Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]]: convert <class 'raco.algebra.Broadcast'> to sql
# WARNING:raco.backends.myria.myria:Error converting Select((((ABS((x - x)) < 0.0042) and (ABS((y - y)) < 0.0042)) and (ABS((z - z)) < 0.0042)))[CrossProduct[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000970)],Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]]: convert <class 'raco.algebra.Broadcast'> to sql
# WARNING:raco.backends.myria.myria:Error converting CrossProduct[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000970)],Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]]: convert <class 'raco.algebra.Broadcast'> to sql
# WARNING:raco.backends.myria.myria:Error converting Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]: convert <class 'raco.algebra.Broadcast'> to sql
# WARNING:raco.backends.myria.myria:Error converting Broadcast[Select(($0 = 68649))[Scan(public:adhoc:cosmo8_000970)]]: convert <class 'raco.algebra.Broadcast'> to sql
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dist</th>
#       <th>eps</th>
#       <th>grp</th>
#       <th>hsmooth</th>
#       <th>iOrder</th>
#       <th>mass</th>
#       <th>metals</th>
#       <th>phi</th>
#       <th>rho</th>
#       <th>temp</th>
#       <th>tform</th>
#       <th>type</th>
#       <th>vx</th>
#       <th>vy</th>
#       <th>vz</th>
#       <th>x</th>
#       <th>y</th>
#       <th>z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.003210</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>16649770</td>
#       <td>2.875926e-09</td>
#       <td>5.964254e-08</td>
#       <td>0.061627</td>
#       <td>0.256895</td>
#       <td>43294.468750</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.469772</td>
#       <td>-0.142361</td>
#       <td>0.532400</td>
#       <td>-0.429127</td>
#       <td>0.479288</td>
#       <td>-0.434219</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.002667</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>16650026</td>
#       <td>2.875926e-09</td>
#       <td>1.157791e-06</td>
#       <td>0.059782</td>
#       <td>0.264447</td>
#       <td>45130.902344</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.441069</td>
#       <td>-0.332690</td>
#       <td>0.491269</td>
#       <td>-0.428067</td>
#       <td>0.481917</td>
#       <td>-0.429749</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.002449</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>68137</td>
#       <td>2.875926e-09</td>
#       <td>1.040890e-06</td>
#       <td>0.059954</td>
#       <td>0.451060</td>
#       <td>83008.171875</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.344867</td>
#       <td>-0.024770</td>
#       <td>0.414122</td>
#       <td>-0.430782</td>
#       <td>0.479557</td>
#       <td>-0.433129</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.004190</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>198952</td>
#       <td>2.875926e-09</td>
#       <td>7.115757e-06</td>
#       <td>0.057881</td>
#       <td>0.397624</td>
#       <td>70646.054688</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.341562</td>
#       <td>-0.224246</td>
#       <td>0.337227</td>
#       <td>-0.429081</td>
#       <td>0.482728</td>
#       <td>-0.427878</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.003813</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>396575</td>
#       <td>2.876051e-09</td>
#       <td>8.862437e-05</td>
#       <td>0.056344</td>
#       <td>0.409967</td>
#       <td>122541.750000</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>0.163661</td>
#       <td>-0.028602</td>
#       <td>0.578346</td>
#       <td>-0.432192</td>
#       <td>0.478819</td>
#       <td>-0.428809</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.002730</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>458787</td>
#       <td>2.875926e-09</td>
#       <td>3.333659e-05</td>
#       <td>0.057491</td>
#       <td>0.344818</td>
#       <td>103199.539062</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>0.082521</td>
#       <td>0.301062</td>
#       <td>0.180324</td>
#       <td>-0.431968</td>
#       <td>0.480836</td>
#       <td>-0.430287</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.004071</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>523550</td>
#       <td>2.875926e-09</td>
#       <td>3.605808e-05</td>
#       <td>0.058153</td>
#       <td>0.450695</td>
#       <td>129690.390625</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>0.206640</td>
#       <td>0.001635</td>
#       <td>0.388153</td>
#       <td>-0.432930</td>
#       <td>0.478700</td>
#       <td>-0.432747</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.003011</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>68393</td>
#       <td>2.875926e-09</td>
#       <td>3.496804e-08</td>
#       <td>0.062103</td>
#       <td>0.163372</td>
#       <td>25344.623047</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.779254</td>
#       <td>-0.407935</td>
#       <td>0.742856</td>
#       <td>-0.426854</td>
#       <td>0.481199</td>
#       <td>-0.432169</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.003533</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>198953</td>
#       <td>2.875926e-09</td>
#       <td>2.381831e-05</td>
#       <td>0.057731</td>
#       <td>0.388437</td>
#       <td>70052.546875</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.237478</td>
#       <td>-0.088838</td>
#       <td>0.225097</td>
#       <td>-0.430471</td>
#       <td>0.482638</td>
#       <td>-0.428864</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.003843</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>263720</td>
#       <td>2.875926e-09</td>
#       <td>2.626564e-06</td>
#       <td>0.059539</td>
#       <td>0.474780</td>
#       <td>98785.703125</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.198770</td>
#       <td>-0.001128</td>
#       <td>0.343280</td>
#       <td>-0.431834</td>
#       <td>0.478784</td>
#       <td>-0.433859</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0.003370</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>328744</td>
#       <td>2.875926e-09</td>
#       <td>1.977028e-06</td>
#       <td>0.060474</td>
#       <td>0.397583</td>
#       <td>109780.437500</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.214385</td>
#       <td>0.033281</td>
#       <td>0.321664</td>
#       <td>-0.430251</td>
#       <td>0.478130</td>
#       <td>-0.433740</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>0.002691</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>329000</td>
#       <td>2.875926e-09</td>
#       <td>1.114516e-05</td>
#       <td>0.058791</td>
#       <td>0.461795</td>
#       <td>98750.921875</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.456567</td>
#       <td>-0.025868</td>
#       <td>0.290514</td>
#       <td>-0.431906</td>
#       <td>0.480562</td>
#       <td>-0.432205</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>0.002591</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>16323624</td>
#       <td>2.875926e-09</td>
#       <td>3.965785e-07</td>
#       <td>0.060823</td>
#       <td>0.262628</td>
#       <td>52022.566406</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.523413</td>
#       <td>-0.382426</td>
#       <td>0.395408</td>
#       <td>-0.430112</td>
#       <td>0.481489</td>
#       <td>-0.433250</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>0.003962</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>16650281</td>
#       <td>2.875926e-09</td>
#       <td>1.143463e-06</td>
#       <td>0.058384</td>
#       <td>0.396397</td>
#       <td>71281.289062</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.713831</td>
#       <td>-0.097779</td>
#       <td>0.476638</td>
#       <td>-0.432521</td>
#       <td>0.482611</td>
#       <td>-0.431628</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>0.003052</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>16715050</td>
#       <td>2.875926e-09</td>
#       <td>4.304838e-08</td>
#       <td>0.062091</td>
#       <td>0.204497</td>
#       <td>29993.513672</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.719951</td>
#       <td>-0.331257</td>
#       <td>0.624576</td>
#       <td>-0.426765</td>
#       <td>0.479531</td>
#       <td>-0.432414</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>0.000000</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>68649</td>
#       <td>2.875926e-09</td>
#       <td>3.064064e-06</td>
#       <td>0.059639</td>
#       <td>0.317765</td>
#       <td>54363.511719</td>
#       <td>0.0</td>
#       <td>gas</td>
#       <td>-0.501991</td>
#       <td>-0.283368</td>
#       <td>0.436636</td>
#       <td>-0.429473</td>
#       <td>0.480128</td>
#       <td>-0.431140</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>0.001790</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0.00004</td>
#       <td>198697</td>
#       <td>2.875926e-09</td>

# %% [markdown]
# There is also special syntax for user defined aggregate functions, which use all of the rows to produce a single output, like a Reduce or Fold function pattern:
#
# ```
# uda func-name(args) {
#  initialization-expr(s);
#  update-expr(s);
#  result-expr(s);
# };
# ```
#
# Where each of the inner lines is a bracketed statement with an entry for each expression that you want to output.

# %%
# %%query
# -- UDA example using MyriaL functions inside the UDA update line
# def pickBasedOnValue2(val1, arg1, val2, arg2):
#     case
#         when val1 >= val2
#         then arg1
#         else arg2
#     end;
#
# def maxValue2(val1, val2):
#     case
#         when val1 >= val2
#         then val1
#         else val2
#     end;
#
# uda argMaxAndMax(arg, val) {
#     [-1 as argAcc, -1.0 as valAcc];
#
#     [pickBasedOnValue2(val, arg, valAcc, argAcc),
#      maxValue2(val, valAcc)];
#
#     [argAcc, valAcc];
# };
#
# cosmo8 = scan(cosmo8_000970);
# res = select argMaxAndMax(iOrder, vx) from cosmo8;
# store(res, garbage);
# Out:
# WARNING:raco.backends.myria.myria:Error converting Store(public:adhoc:garbage)[MyriaGroupBy(; UDA(argAcc__7),UDA(valAcc__8))[Collect(@None)[Apply(iOrder=$0,vx=$5)[Scan(public:adhoc:cosmo8_000970)]]]]: convert <class 'raco.algebra.Collect'> to sql
# WARNING:raco.backends.myria.myria:Error converting MyriaGroupBy(; UDA(argAcc__7),UDA(valAcc__8))[Collect(@None)[Apply(iOrder=$0,vx=$5)[Scan(public:adhoc:cosmo8_000970)]]]: convert <class 'raco.algebra.Collect'> to sql
# WARNING:raco.backends.myria.myria:Error converting Collect(@None)[Apply(iOrder=$0,vx=$5)[Scan(public:adhoc:cosmo8_000970)]]: convert <class 'raco.algebra.Collect'> to sql
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>uda0</th>
#       <th>uda1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>33655242</td>
#       <td>13.730947</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Previously when we wrote a UDF we expected the tuplList to only hold one row
# but UDFs that are used in a UDA could be given many rows at a time, so it is
# important to loop over all of them and keep track of the state/accumulator outside
# the loop, and then return the value that is expected by the update-expr line in the UDA.
from raco.types import LONG_TYPE
def pickBasedOnValue(tuplList):
    maxArg = -1
    maxVal = -1.0
    
    for tupl in tuplList:
        value1 = tupl[0]
        arg1 = tupl[1]
        value2 = tupl[2]
        arg2 = tupl[3]
        if (value1 >= value2):
            if (value1 >= maxVal):
                maxArg = arg1
                maxVal = value1
        else:
            if (value2 >= maxVal):
                maxArg = arg2
                maxVal = value2
    return maxArg

MyriaPythonFunction(pickBasedOnValue, LONG_TYPE).register()

from raco.types import DOUBLE_TYPE
def maxValue(tuplList):
    maxVal = -1.0
    
    for tupl in tuplList:
        value1 = tupl[0]
        value2 = tupl[1]
        if (value1 >= value2):
            if (value1 >= maxVal):
                maxVal = value1
        else:
            if (value2 >= maxVal):
                maxVal = value2
    return maxVal

MyriaPythonFunction(maxValue, DOUBLE_TYPE).register()

# %%
# %%query
# -- UDA example using Python functions inside the UDA update line
# uda argMaxAndMax(arg, val) {
#     [-1 as argAcc, -1.0 as valAcc];
#
#     [pickBasedOnValue(val, arg, valAcc, argAcc),
#      maxValue(val, valAcc)];
#
#     [argAcc, valAcc];
# };
# t = scan(cosmo8_000970);
# s = select argMaxAndMax(iOrder, vx) from t;
# store(s, garbage);
# Out:
# WARNING:raco.backends.myria.myria:Error converting Store(public:adhoc:garbage)[MyriaGroupBy(; UDA(argAcc__19),UDA(valAcc__20))[Collect(@None)[Apply(iOrder=$0,vx=$5)[Scan(public:adhoc:cosmo8_000970)]]]]: convert <class 'raco.algebra.Collect'> to sql
# WARNING:raco.backends.myria.myria:Error converting MyriaGroupBy(; UDA(argAcc__19),UDA(valAcc__20))[Collect(@None)[Apply(iOrder=$0,vx=$5)[Scan(public:adhoc:cosmo8_000970)]]]: convert <class 'raco.algebra.Collect'> to sql
# WARNING:raco.backends.myria.myria:Error converting Collect(@None)[Apply(iOrder=$0,vx=$5)[Scan(public:adhoc:cosmo8_000970)]]: convert <class 'raco.algebra.Collect'> to sql
# TypeErrorTraceback (most recent call last)
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     336             method = get_real_method(obj, self.print_method)
#     337             if method is not None:
# --> 338                 return method()
#     339             return None
#     340         else:
#
# /usr/local/lib/python2.7/dist-packages/myria_python-1.3.1-py2.7.egg/myria/query.pyc in _repr_html_(self)
#     128         """ Generate a representation of this query as HTML """
#     129         return self.to_dataframe().to_html() \
# --> 130             if self.status not in self.nonterminal_states \
#     131             else '<{}, status={}>'.format(self.__class__.__name__, self.status)
#     132
#
# /usr/local/lib/python2.7/dist-packages/myria_python-1.3.1-py2.7.egg/myria/query.pyc in to_dataframe(self, index)
#     123                               'Pandas DataFrames')
#     124         else:
# --> 125             return DataFrame.from_records(self.to_dict(), index=index)
#     126
#     127     def _repr_html_(self):
#
# /usr/local/lib/python2.7/dist-packages/myria_python-1.3.1-py2.7.egg/myria/query.pyc in to_dict(self)
#     115         """ Download the JSON results of the query """
#     116         self.wait_for_completion()
# --> 117         return self.connection.download_dataset(self.qualified_name)
#     118
#     119     def to_dataframe(self, index=None):
#
# /usr/local/lib/python2.7/dist-packages/myria_python-1.3.1-py2.7.egg/myria/connection.pyc in download_dataset(self, relation_key)
#     243         """Download the data in the dataset as json"""
#     244         return self._wrap_get('/dataset/user-{}/program-{}/relation-{}/data'
# --> 245                               .format(relation_key['userName'],
#     246                                       relation_key['programName'],
#     247                                       relation_key['relationName']),
#
# TypeError: 'NoneType' object has no attribute '__getitem__'

# %%
# %%query
# -- of course, argMaxAndMax can be done much more simply:
# c = scan(cosmo8_000970);
# m = select max(vx) as mvx from c;
# res = select iOrder, mvx from m,c where vx = mvx;
# store(res, garbage);
# Out:
# WARNING:raco.backends.myria.myria:Error converting Store(public:adhoc:garbage)[Apply(iOrder=$1,mvx=$0)[ProjectingJoin(($2 = $0); $0,$1)[Shuffle(Hash($0))[Apply(mvx=$0)[MyriaGroupBy(; MAX($0))[Collect(@None)[MyriaGroupBy(; MAX($0))[Apply(vx=$5)[Scan(public:adhoc:cosmo8_000970)]]]]]],Shuffle(Hash($1))[Apply(iOrder=$0,vx=$5)[Scan(public:adhoc:cosmo8_000970)]]]]]: convert <class 'raco.algebra.Collect'> to sql
# WARNING:raco.backends.myria.myria:Error converting Apply(iOrder=$1,mvx=$0)[ProjectingJoin(($2 = $0); $0,$1)[Shuffle(Hash($0))[Apply(mvx=$0)[MyriaGroupBy(; MAX($0))[Collect(@None)[MyriaGroupBy(; MAX($0))[Apply(vx=$5)[Scan(public:adhoc:cosmo8_000970)]]]]]],Shuffle(Hash($1))[Apply(iOrder=$0,vx=$5)[Scan(public:adhoc:cosmo8_000970)]]]]: convert <class 'raco.algebra.Collect'> to sql
# WARNING:raco.backends.myria.myria:Error converting ProjectingJoin(($2 = $0); $0,$1)[Shuffle(Hash($0))[Apply(mvx=$0)[MyriaGroupBy(; MAX($0))[Collect(@None)[MyriaGroupBy(; MAX($0))[Apply(vx=$5)[Scan(public:adhoc:cosmo8_000970)]]]]]],Shuffle(Hash($1))[Apply(iOrder=$0,vx=$5)[Scan(public:adhoc:cosmo8_000970)]]]: convert <class 'raco.algebra.Collect'> to sql
# WARNING:raco.backends.myria.myria:Error converting Shuffle(Hash($0))[Apply(mvx=$0)[MyriaGroupBy(; MAX($0))[Collect(@None)[MyriaGroupBy(; MAX($0))[Apply(vx=$5)[Scan(public:adhoc:cosmo8_000970)]]]]]]: convert <class 'raco.algebra.Collect'> to sql
# WARNING:raco.backends.myria.myria:Error converting Apply(mvx=$0)[MyriaGroupBy(; MAX($0))[Collect(@None)[MyriaGroupBy(; MAX($0))[Apply(vx=$5)[Scan(public:adhoc:cosmo8_000970)]]]]]: convert <class 'raco.algebra.Collect'> to sql
# WARNING:raco.backends.myria.myria:Error converting MyriaGroupBy(; MAX($0))[Collect(@None)[MyriaGroupBy(; MAX($0))[Apply(vx=$5)[Scan(public:adhoc:cosmo8_000970)]]]]: convert <class 'raco.algebra.Collect'> to sql
# WARNING:raco.backends.myria.myria:Error converting Collect(@None)[MyriaGroupBy(; MAX($0))[Apply(vx=$5)[Scan(public:adhoc:cosmo8_000970)]]]: convert <class 'raco.algebra.Collect'> to sql
# WARNING:raco.backends.myria.myria:Error converting Shuffle(Hash($1))[Apply(iOrder=$0,vx=$5)[Scan(public:adhoc:cosmo8_000970)]]: convert <class 'raco.algebra.Shuffle'> to sql
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>iOrder</th>
#       <th>mvx</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>33655242</td>
#       <td>13.730947</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Working with multiple snapshots

# %% [markdown]
# On the Myria demo cluster we only provide cosmo8_000970, but on a private cluster we could load in any number of snapshots to look for how things change over time.

# %%
# %%query
# c8_000970 = scan(cosmo8_000970);
# c8_000962 = scan(cosmo8_000962);
#
# -- finding all gas particles that were destroyed between step 000962 and 000970
# c1Gases = select iOrder from c8_000962 where type = 'gas';
# c2Gases = select iOrder from c8_000970 where type = 'gas';
#
# exist = select c1.iOrder from c1Gases as c1, c2Gases as c2 where c1.iOrder = c2.iOrder;
#
# destroyed = diff(c1Gases, exist);
# store(destroyed, garbage);
# Out:
# WARNING:raco.backends.myria.myria:Error converting Store(public:adhoc:garbage)[Difference[Shuffle(Hash($0))[Apply(iOrder=iOrder)[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000962)]]],Shuffle(Hash($0))[ProjectingJoin(($0 = $1); $0)[Shuffle(Hash($0))[Apply(iOrder=iOrder)[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000962)]]],Shuffle(Hash($0))[Apply(iOrder=iOrder)[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000970)]]]]]]]: convert <class 'raco.algebra.Shuffle'> to sql
# WARNING:raco.backends.myria.myria:Error converting Difference[Shuffle(Hash($0))[Apply(iOrder=iOrder)[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000962)]]],Shuffle(Hash($0))[ProjectingJoin(($0 = $1); $0)[Shuffle(Hash($0))[Apply(iOrder=iOrder)[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000962)]]],Shuffle(Hash($0))[Apply(iOrder=iOrder)[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000970)]]]]]]: convert <class 'raco.algebra.Shuffle'> to sql
# WARNING:raco.backends.myria.myria:Error converting Shuffle(Hash($0))[Apply(iOrder=iOrder)[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000962)]]]: convert <class 'raco.algebra.Shuffle'> to sql
# WARNING:raco.backends.myria.myria:Error converting Shuffle(Hash($0))[ProjectingJoin(($0 = $1); $0)[Shuffle(Hash($0))[Apply(iOrder=iOrder)[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000962)]]],Shuffle(Hash($0))[Apply(iOrder=iOrder)[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000970)]]]]]: convert <class 'raco.algebra.Shuffle'> to sql
# WARNING:raco.backends.myria.myria:Error converting ProjectingJoin(($0 = $1); $0)[Shuffle(Hash($0))[Apply(iOrder=iOrder)[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000962)]]],Shuffle(Hash($0))[Apply(iOrder=iOrder)[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000970)]]]]: convert <class 'raco.algebra.Shuffle'> to sql
# WARNING:raco.backends.myria.myria:Error converting Shuffle(Hash($0))[Apply(iOrder=iOrder)[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000962)]]]: convert <class 'raco.algebra.Shuffle'> to sql
# WARNING:raco.backends.myria.myria:Error converting Shuffle(Hash($0))[Apply(iOrder=iOrder)[Select(($16 = "gas"))[Scan(public:adhoc:cosmo8_000970)]]]: convert <class 'raco.algebra.Shuffle'> to sql
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>iOrder</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>54437</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>64022</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>78352</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>91698</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>93746</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>94516</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>128434</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>189875</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>221476</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>287535</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>291356</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>343583</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>386694</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>397309</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>409892</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>410140</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>452286</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>456095</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>483875</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>543231</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>16379</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>589308</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>591371</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>90674</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>92456</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>115621</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>621079</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>648873</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>127383</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>127649</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>157240</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>187582</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>209445</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>229166</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>278552</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>674328</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>683564</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>314314</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>315276</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>327942</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>719773</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>735225</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>738824</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>380061</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>388537</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>392704</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>418356</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>447898</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>454289</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>490523</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>779972</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>545288</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>557610</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>558123</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>579998</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>646814</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>673783</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>683045</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>721917</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>785395</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>800526</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>817171</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>748815</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>790286</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>801530</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>839362</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>840909</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>841904</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>852995</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>866303</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>853003</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>907200</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>921075</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>932596</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>970164</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>972469</td>
#     </tr>
#     <tr>
#       <th>76</th>
#       <td>879640</td>
#     </tr>
#     <tr>
#       <th>77</th>
#       <td>884509</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>1055504</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>1133051</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>1144098</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>1144103</td>
#     </tr>
#     <tr>
#       <th>82</th>
#       <td>1170637</td>
#     </tr>
#     <tr>
#       <th>83</th>
#       <td>1177098</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td>1178644</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>917272</td>
#     </tr>
#     <tr>
#       <th>86</th>
#       <td>1250037</td>
#     </tr>
#     <tr>
#       <th>87</th>
#       <td>1263360</td>
#     </tr>
#     <tr>
#       <th>88</th>
#       <td>1264146</td>
#     </tr>
#     <tr>
#       <th>89</th>
#       <td>1313818</td>
#     </tr>
#     <tr>
#       <th>90</th>
#       <td>1315832</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>1329686</td>
#     </tr>
#     <tr>
#       <th>92</th>
#       <td>1334586</td>
#     </tr>
#     <tr>
#       <th>93</th>
#       <td>1341477</td>
#     </tr>
#     <tr>
#       <th>94</th>
#       <td>947767</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>1377560</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>1409558</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>1001987</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>1003009</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>1012278</td>
#     </tr>
#     <tr>
#       <th>100</th>
#       <td>1458204</td>
#     </tr>
#     <tr>
#       <th>101</th>
#       <td>1459228</td>
#     </tr>
#     <tr>
#       <th>102</th>
#       <td>1459467</td>
#     </tr>
#     <tr>
#       <th>103</th>
#       <td>1503392</td>
#     </tr>
#     <tr>
#       <th>104</th>
#       <td>1052188</td>
#     </tr>
#     <tr>
#       <th>105</th>
#       <td>1063685</td>
#     </tr>
#     <tr>
#       <th>106</th>
#       <td>1067533</td>
#     </tr>
#     <tr>
#       <th>107</th>
#       <td>1523227</td>
#     </tr>
#     <tr>
#       <th>108</th>
#       <td>1538582</td>
#     </tr>
#     <tr>
#       <th>109</th>
#       <td>1575687</td>
#     </tr>
#     <tr>
#       <th>110</th>
#       <td>1581303</td>
#     </tr>
#     <tr>
#       <th>111</th>
#       <td>1591556</td>
#     </tr>
#     <tr>
#       <th>112</th>
#       <td>1113888</td>
#     </tr>
#     <tr>
#       <th>113</th>
#       <td>1120503</td>
#     </tr>
#     <tr>
#       <th>114</th>
#       <td>1142328</td>
#     </tr>
#     <tr>
#       <th>115</th>
#       <td>1142842</td>
#     </tr>
#     <tr>
#       <th>116</th>
#       <td>1666324</td>
#     </tr>
#     <tr>
#       <th>117</th>
#       <td>1703941</td>
#     </tr>
#     <tr>
#       <th>118</th>
#       <td>1709299</td>
#     </tr>
#     <tr>
#       <th>119</th>
#       <td>1173914</td>
#     </tr>
#     <tr>
#       <th>120</th>
#       <td>1185805</td>
#     </tr>
#     <tr>
#       <th>121</th>
#       <td>1203245</td>
#     </tr>
#     <tr>
#       <th>122</th>
#       <td>1203514</td>
#     </tr>
#     <tr>
#       <th>123</th>
#       <td>1721118</td>
#     </tr>
#     <tr>
#       <th>124</th>
#       <td>1721377</td>
#     </tr>
#     <tr>
#       <th>125</th>
#       <td>1735977</td>
#     </tr>
#     <tr>
#       <th>126</th>
#       <td>1241365</td>
#     </tr>
#     <tr>
#       <th>127</th>
#       <td>1307393</td>
#     </tr>
#     <tr>
#       <th>128</th>
#       <td>1307665</td>
#     </tr>
#     <tr>
#       <th>129</th>
#       <td>1309711</td>
#     </tr>
#     <tr>
#       <th>130</th>
#       <td>1336878</td>
#     </tr>
#     <tr>
#       <th>131</th>
#       <td>1930519</td>
#     <

# %%
# %%query
# c8_000970 = scan(cosmo8_000970);
# c8_000962 = scan(cosmo8_000962);
#
# -- finding all particles where some property changed between step 000962 and 000970
# res = select c1.iOrder
#     from c8_000962 as c1, c8_000970 as c2
#     where c1.iOrder = c2.iOrder
#     and c1.metals = 0.0 and c2.metals > 0.0;
# store(res, garbage);
# Out:
# WARNING:raco.backends.myria.myria:Error converting Store(public:adhoc:garbage)[ProjectingJoin(($0 = $1); $0)[Shuffle(Hash($0))[Apply(iOrder=$0)[Select((metals = 0.0))[Scan(public:adhoc:cosmo8_000962)]]],Shuffle(Hash($0))[Apply(iOrder=$0)[Select((metals > 0.0))[Scan(public:adhoc:cosmo8_000970)]]]]]: convert <class 'raco.algebra.Shuffle'> to sql
# WARNING:raco.backends.myria.myria:Error converting ProjectingJoin(($0 = $1); $0)[Shuffle(Hash($0))[Apply(iOrder=$0)[Select((metals = 0.0))[Scan(public:adhoc:cosmo8_000962)]]],Shuffle(Hash($0))[Apply(iOrder=$0)[Select((metals > 0.0))[Scan(public:adhoc:cosmo8_000970)]]]]: convert <class 'raco.algebra.Shuffle'> to sql
# WARNING:raco.backends.myria.myria:Error converting Shuffle(Hash($0))[Apply(iOrder=$0)[Select((metals = 0.0))[Scan(public:adhoc:cosmo8_000962)]]]: convert <class 'raco.algebra.Shuffle'> to sql
# WARNING:raco.backends.myria.myria:Error converting Shuffle(Hash($0))[Apply(iOrder=$0)[Select((metals > 0.0))[Scan(public:adhoc:cosmo8_000970)]]]: convert <class 'raco.algebra.Shuffle'> to sql
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>iOrder</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>105921</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>121618</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>217747</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>369140</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>889864</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>890628</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1056698</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1076317</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1094357</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1207666</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>1345529</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>1357529</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>1359633</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>1372032</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>1389024</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>1390561</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>1391294</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>1430015</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>1449635</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>1451469</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>1501556</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>1589179</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>1738610</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>1784974</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>1640850</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>1983110</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>2067059</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>2072323</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>693251</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>739720</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>739724</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>781924</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>782181</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>794292</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>795596</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>2237134</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>1861543</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>2390187</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>2393090</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>928473</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>2038458</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>2500788</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>2508932</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>2104251</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>2615943</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>2617227</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>2235091</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>2681218</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>1139897</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>1152545</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>1188543</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>1189067</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>1256151</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>1299710</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>1406327</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>1502065</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>1553623</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>1579435</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>1579696</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>1651151</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>1664929</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>2739209</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>2878601</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>2879630</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>2887111</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>3148947</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>3259132</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>3259400</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>2893980</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>2902224</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>2906472</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>2908836</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>2918915</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>3011216</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>3269000</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>1947913</td>
#     </tr>
#     <tr>
#       <th>76</th>
#       <td>2010881</td>
#     </tr>
#     <tr>
#       <th>77</th>
#       <td>3503125</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>3408792</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>3419814</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>2019585</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>2092164</td>
#     </tr>
#     <tr>
#       <th>82</th>
#       <td>3539650</td>
#     </tr>
#     <tr>
#       <th>83</th>
#       <td>3552413</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td>3563409</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>2328177</td>
#     </tr>
#     <tr>
#       <th>86</th>
#       <td>2335981</td>
#     </tr>
#     <tr>
#       <th>87</th>
#       <td>3831090</td>
#     </tr>
#     <tr>
#       <th>88</th>
#       <td>3831406</td>
#     </tr>
#     <tr>
#       <th>89</th>
#       <td>3878306</td>
#     </tr>
#     <tr>
#       <th>90</th>
#       <td>3890290</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>3944390</td>
#     </tr>
#     <tr>
#       <th>92</th>
#       <td>3947210</td>
#     </tr>
#     <tr>
#       <th>93</th>
#       <td>3960958</td>
#     </tr>
#     <tr>
#       <th>94</th>
#       <td>4133562</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>4142426</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>4150146</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>4159890</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>4179954</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>4281475</td>
#     </tr>
#     <tr>
#       <th>100</th>
#       <td>4347268</td>
#     </tr>
#     <tr>
#       <th>101</th>
#       <td>4670408</td>
#     </tr>
#     <tr>
#       <th>102</th>
#       <td>4395703</td>
#     </tr>
#     <tr>
#       <th>103</th>
#       <td>4410836</td>
#     </tr>
#     <tr>
#       <th>104</th>
#       <td>4411784</td>
#     </tr>
#     <tr>
#       <th>105</th>
#       <td>4720051</td>
#     </tr>
#     <tr>
#       <th>106</th>
#       <td>4733893</td>
#     </tr>
#     <tr>
#       <th>107</th>
#       <td>4742729</td>
#     </tr>
#     <tr>
#       <th>108</th>
#       <td>4821881</td>
#     </tr>
#     <tr>
#       <th>109</th>
#       <td>3161179</td>
#     </tr>
#     <tr>
#       <th>110</th>
#       <td>3164995</td>
#     </tr>
#     <tr>
#       <th>111</th>
#       <td>3165043</td>
#     </tr>
#     <tr>
#       <th>112</th>
#       <td>3167315</td>
#     </tr>
#     <tr>
#       <th>113</th>
#       <td>3235321</td>
#     </tr>
#     <tr>
#       <th>114</th>
#       <td>4887930</td>
#     </tr>
#     <tr>
#       <th>115</th>
#       <td>3356874</td>
#     </tr>
#     <tr>
#       <th>116</th>
#       <td>3375467</td>
#     </tr>
#     <tr>
#       <th>117</th>
#       <td>5217151</td>
#     </tr>
#     <tr>
#       <th>118</th>
#       <td>5324879</td>
#     </tr>
#     <tr>
#       <th>119</th>
#       <td>5278306</td>
#     </tr>
#     <tr>
#       <th>120</th>
#       <td>5425101</td>
#     </tr>
#     <tr>
#       <th>121</th>
#       <td>5333555</td>
#     </tr>
#     <tr>
#       <th>122</th>
#       <td>5334327</td>
#     </tr>
#     <tr>
#       <th>123</th>
#       <td>5335347</td>
#     </tr>
#     <tr>
#       <th>124</th>
#       <td>5340459</td>
#     </tr>
#     <tr>
#       <th>125</th>
#       <td>5454418</td>
#     </tr>
#     <tr>
#       <th>126</th>
#       <td>5459066</td>
#     </tr>
#     <tr>
#       <th>127</th>
#       <td>5459650</td>
#     </tr>
#     <tr>
#       <th>128</th>
#       <td>3700516</td>
#     </tr>
#     <tr>
#       <th>129</th>
#       <td>3703979</td>
#     </tr>
#     <tr>
#       <th>130</th>
#       <td>3704

# %%
from IPython.display import HTML
HTML('''<script>
code_show_err=false; 
function code_toggle_err() {
 if (code_show_err){
 $('div.output_stderr').hide();
 } else {
 $('div.output_stderr').show();
 }
 code_show_err = !code_show_err
} 
$( document ).ready(code_toggle_err);
</script>
To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.''')
# Out:
# <script>
# code_show_err=false;
# function code_toggle_err() {
#  if (code_show_err){
#  $('div.output_stderr').hide();
#  } else {
#  $('div.output_stderr').show();
#  }
#  code_show_err = !code_show_err
# }
# $( document ).ready(code_toggle_err);
# </script>
# To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.
